# %%
import pandas as pd
regions = pd.read_csv('regions.csv')
regions.head()
# Out:
#    region_id      region  population  area_sq_km
# 0          1       Bihar  90048646.0      207448
# 1          2     Gujarat         NaN      122562
# 2          3      Odisha         NaN       95079
# 3          4      Kerala         NaN      206605
# 4          5  Tamil Nadu  15204415.0      154926

# %%
regions = regions.drop_duplicates()

# %%
len(regions)
# Out:
# 1000

# %%
regions["population"] = regions["population"].fillna(regions["population"].median())

# %%
regions.to_csv("regions_cleaned.csv" , index = False)

# %%
regions.describe()
# Out:
#          region_id    population     area_sq_km
# count  1000.000000  1.000000e+03    1000.000000
# mean    500.500000  5.149123e+07  140651.010000
# std     288.819436  1.922303e+07   62132.013401
# min       1.000000  5.072871e+06   30051.000000
# 25%     250.750000  5.114027e+07   85252.750000
# 50%     500.500000  5.118973e+07  142487.000000
# 75%     750.250000  5.129802e+07  192012.250000
# max    1000.000000  9.981206e+07  249575.000000

# %%
print(regions["population"].median()) #imputing with median is safer because it prevents skews -
# Out:
# 51189726.0

# %%
print(regions["population"].mean())
# Out:
# 51491230.056

# %%
len(regions)
# Out:
# 1000

# %%
regions.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region_id   1000 non-null   int64
#  1   region      1000 non-null   str
#  2   population  1000 non-null   float64
#  3   area_sq_km  1000 non-null   int64
# dtypes: float64(1), int64(2), str(1)
# memory usage: 31.4 KB

# %%
(regions["population"] < 0).sum()
# Out:
# np.int64(0)

# %%
(regions["area_sq_km"] < 0).sum()
# Out:
# np.int64(0)

# %%
len(regions)
# Out:
# 1000

# %%
regions.to_csv("regions.csv",index = False)

# %%
impact_assessment = pd.read_csv("impact_assessment.csv")
display(impact_assessment)
# Out:
#       impact_id  event_id  affected_people  economic_loss_musd
# 0             1       999         250020.0              989.93
# 1             2       225        2198805.0             1699.75
# 2             3       183        1645062.0                 NaN
# 3             4       933         849845.0             4157.40
# 4             5       389              NaN                 NaN
# ...         ...       ...              ...                 ...
# 1055        340       154              NaN                 NaN
# 1056        318       122        3025038.0             4478.04
# 1057        874       161              NaN                 NaN
# 1058        845        42              NaN             1864.60
# 1059        920       327         613825.0                 NaN
#
# [1060 rows x 4 columns]

# %%
impact_assessment.describe()
# Out:
#          impact_id     event_id  affected_people  economic_loss_musd
# count  1060.000000  1060.000000     5.450000e+02          511.000000
# mean    503.443396   483.782075     2.457120e+06         2447.832250
# std     290.338257   282.961798     1.447452e+06         1466.194703
# min       1.000000     1.000000     1.717000e+03            7.050000
# 25%     251.750000   248.000000     1.197514e+06         1095.070000
# 50%     505.500000   468.000000     2.420529e+06         2495.040000
# 75%     756.250000   716.250000     3.740980e+06         3717.845000
# max    1000.000000   999.000000     4.986682e+06         4976.820000

# %%
print(impact_assessment["affected_people"].median())
# Out:
# 2420529.0

# %%
print(impact_assessment["affected_people"].mean())
# Out:
# 2457120.2935779816

# %%
print(regions.dtypes)
# Out:
# region_id       int64
# region            str
# population    float64
# area_sq_km      int64
# dtype: object

# %%
print(impact_assessment.dtypes)
# Out:
# impact_id               int64
# event_id                int64
# affected_people       float64
# economic_loss_musd    float64
# dtype: object

# %%
print(impact_assessment["economic_loss_musd"].mean())
# Out:
# 2447.8322504892362

# %%
print(impact_assessment["economic_loss_musd"].median())
# Out:
# 2495.04

# %%
impact_assessment = impact_assessment.drop_duplicates()
len(impact_assessment)
# Out:
# 1000

# %%
print(impact_assessment.isnull().sum())
# Out:
# impact_id               0
# event_id                0
# affected_people       483
# economic_loss_musd    523
# dtype: int64

# %%
impact_assessment["affected_people"] = impact_assessment["affected_people"].fillna(0)
impact_assessment["economic_loss_musd"] = impact_assessment["economic_loss_musd"].fillna(0)

# %%
print(impact_assessment.isnull().sum())
# Out:
# impact_id             0
# event_id              0
# affected_people       0
# economic_loss_musd    0
# dtype: int64

# %%
(impact_assessment["affected_people"] <0).sum()
# Out:
# np.int64(0)

# %%
(impact_assessment["economic_loss_musd"] < 0).sum()
# Out:
# np.int64(0)

# %%
impact_assessment.to_csv('impact_assessment_cleaned.csv',index = False)

# %%
print(impact_assessment.isnull().sum())
# Out:
# impact_id             0
# event_id              0
# affected_people       0
# economic_loss_musd    0
# dtype: int64

# %%
disaster_events = pd.read_csv('disaster_events.csv')
len(disaster_events)
# Out:
# 1050

# %%
disaster_events.isnull().sum()
# Out:
# event_id           0
# disaster_type    185
# region             0
# event_date        48
# severity           0
# dtype: int64

# %%
disaster_events["disaster_type"] = disaster_events["disaster_type"].fillna("Unknown")
disaster_events.isnull().sum()
# Out:
# event_id          0
# disaster_type     0
# region            0
# event_date       48
# severity          0
# dtype: int64

# %%
disaster_events.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   event_id       1050 non-null   int64
#  1   disaster_type  1050 non-null   str
#  2   region         1050 non-null   str
#  3   event_date     1002 non-null   str
#  4   severity       1050 non-null   str
# dtypes: int64(1), str(4)
# memory usage: 41.1 KB

# %%
disaster_events["event_date"] = pd.to_datetime(disaster_events["event_date"], errors="coerce")

# %%
disaster_events.head()
# Out:
#    event_id disaster_type       region event_date severity
# 0         1       Unknown  West Bengal        NaT   Medium
# 1         2       Cyclone      Gujarat 2021-07-29     High
# 2         3       Unknown  West Bengal 2021-03-07      Low
# 3         4         Flood      Gujarat 2021-02-24     High
# 4         5       Cyclone        Bihar 2022-07-24      Low

# %%
import pandas as pd
disaster_events["event_date"] = disaster_events["event_date"].fillna(pd.Timestamp("1990-01-01"))

# %%
disaster_events.isnull().sum()
# Out:
# event_id         0
# disaster_type    0
# region           0
# event_date       0
# severity         0
# dtype: int64

# %%
disaster_events.head()
# Out:
#    event_id disaster_type       region event_date severity
# 0         1       Unknown  West Bengal 1990-01-01   Medium
# 1         2       Cyclone      Gujarat 2021-07-29     High
# 2         3       Unknown  West Bengal 2021-03-07      Low
# 3         4         Flood      Gujarat 2021-02-24     High
# 4         5       Cyclone        Bihar 2022-07-24      Low

# %%
disaster_events = disaster_events.drop_duplicates()
len(disaster_events)
# Out:
# 1000

# %%
disaster_events.head()
# Out:
#    event_id disaster_type       region event_date severity
# 0         1       Unknown  West Bengal 1990-01-01   Medium
# 1         2       Cyclone      Gujarat 2021-07-29     High
# 2         3       Unknown  West Bengal 2021-03-07      Low
# 3         4         Flood      Gujarat 2021-02-24     High
# 4         5       Cyclone        Bihar 2022-07-24      Low

# %%
disaster_events.to_csv('disaster_events_cleaned.csv',index = False)

# %%
# !pip install pandas mysql-connector-python sqlalchemy
# Out:
# Requirement already satisfied: pandas in c:\users\kavya\appdata\roaming\python\python314\site-packages (3.0.0)
# Requirement already satisfied: mysql-connector-python in c:\users\kavya\appdata\roaming\python\python314\site-packages (9.6.0)
# Requirement already satisfied: sqlalchemy in c:\users\kavya\appdata\roaming\python\python314\site-packages (2.0.46)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\kavya\appdata\roaming\python\python314\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kavya\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\kavya\appdata\roaming\python\python314\site-packages (from pandas) (2025.3)
# Requirement already satisfied: greenlet>=1 in c:\users\kavya\appdata\roaming\python\python314\site-packages (from sqlalchemy) (3.3.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\kavya\appdata\roaming\python\python314\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\kavya\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

password = quote_plus("KavyaKothapalli@123")

engine = create_engine(
    f"mysql+mysqlconnector://root:{password}@localhost:3306/data"
)

# %%
regions.to_sql("regions", engine, if_exists="append", index=False)
impact_assessment.to_sql("impact_assessment", engine, if_exists="append", index=False)
disaster_events.to_sql("disaster_events", engine, if_exists="append", index=False)

# %%
query = """
SELECT d.region,
       SUM(i.affected_people) AS total_affected
FROM disaster_events d
JOIN impact_assessment i
    ON d.event_id = i.event_id
GROUP BY d.region
ORDER BY total_affected DESC
LIMIT 5;
"""

top_regions = pd.read_sql(query, con=engine)
top_regions
# Out:
#         region  total_affected
# 0  West Bengal     171433034.0
# 1           UP     167685642.0
# 2   Tamil Nadu     167556762.0
# 3        Bihar     165850182.0
# 4      Gujarat     158766452.0

# %%
query = """
SELECT disaster_type,
       COUNT(*) AS disaster_count
FROM disaster_events
GROUP BY disaster_type
ORDER BY disaster_count DESC;
"""

severity_dist = pd.read_sql(query, con=engine)
severity_dist
# Out:
#   disaster_type  disaster_count
# 0       Unknown             178
# 1       Drought             173
# 2     Landslide             168
# 3       Cyclone             166
# 4         Flood             159
# 5    Earthquake             156

# %%
query = """
SELECT YEAR(event_date) AS year,
       MONTH(event_date) AS month,
       COUNT(*) AS disaster_count
FROM disaster_events
GROUP BY year, month
ORDER BY year, month;
"""

monthly_trend = pd.read_sql(query, con=engine)
monthly_trend
# Out:
#     year  month  disaster_count
# 0   1990      1              43
# 1   2021      1              18
# 2   2021      2               9
# 3   2021      3              30
# 4   2021      4              26
# 5   2021      5              22
# 6   2021      6              37
# 7   2021      7              28
# 8   2021      8              28
# 9   2021      9              18
# 10  2021     10              24
# 11  2021     11              24
# 12  2021     12              30
# 13  2022      1              15
# 14  2022      2              20
# 15  2022      3              17
# 16  2022      4              21
# 17  2022      5              25
# 18  2022      6              22
# 19  2022      7              28
# 20  2022      8              25
# 21  2022      9              29
# 22  2022     10              24
# 23  2022     11              25
# 24  2022     12              19
# 25  2023      1              30
# 26  2023      2              25
# 27  2023      3              24
# 28  2023      4              26
# 29  2023      5              23
# 30  2023      6              20
# 31  2023      7              27
# 32  2023      8              23
# 33  2023      9              25
# 34  2023     10              23
# 35  2023     11              27
# 36  2023     12              22
# 37  2024      1              28
# 38  2024      2              28
# 39  2024      3              33
# 40  2024      4               9

# %%
query = """
SELECT i.affected_people,
       i.economic_loss_musd
FROM impact_assessment i;
"""

scatter_data = pd.read_sql(query, con=engine)
scatter_data
# Out:
#      affected_people  economic_loss_musd
# 0           250020.0              989.93
# 1          2198805.0             1699.75
# 2          1645062.0                0.00
# 3           849845.0             4157.40
# 4                0.0                0.00
# ..               ...                 ...
# 995              0.0             3109.95
# 996              0.0                0.00
# 997              0.0                0.00
# 998        4406735.0              791.70
# 999        1869140.0             2099.99
#
# [1000 rows x 2 columns]

# %%
query = """
SELECT d.region,
       d.disaster_type,
       COUNT(*) AS disaster_count
FROM disaster_events d
GROUP BY d.region, d.disaster_type;
"""

heatmap_data = pd.read_sql(query, con=engine)
heatmap_data
# Out:
#          region disaster_type  disaster_count
# 0   West Bengal       Unknown              33
# 1       Gujarat       Cyclone              21
# 2       Gujarat         Flood              25
# 3         Bihar       Cyclone              23
# 4   West Bengal    Earthquake              23
# 5        Kerala    Earthquake              23
# 6         Bihar         Flood              25
# 7    Tamil Nadu       Drought              19
# 8       Gujarat       Unknown              17
# 9    Tamil Nadu    Earthquake              11
# 10   Tamil Nadu         Flood              20
# 11           UP       Unknown              22
# 12       Kerala       Unknown              20
# 13   Tamil Nadu     Landslide              30
# 14  West Bengal     Landslide              22
# 15        Assam       Unknown              19
# 16       Odisha    Earthquake              16
# 17       Kerala       Drought              20
# 18        Bihar    Earthquake              19
# 19       Kerala         Flood              20
# 20        Assam       Cyclone              24
# 21       Odisha       Drought              25
# 22           UP       Cyclone              24
# 23        Bihar       Drought              19
# 24   Tamil Nadu       Unknown              26
# 25      Gujarat       Drought              27
# 26       Odisha       Unknown              18
# 27        Assam       Drought              21
# 28      Gujarat     Landslide              14
# 29  West Bengal         Flood              17
# 30           UP     Landslide              27
# 31        Assam     Landslide              25
# 32       Odisha         Flood              18
# 33           UP       Drought              20
# 34        Assam    Earthquake              26
# 35      Gujarat    Earthquake              17
# 36       Odisha       Cyclone              17
# 37  West Bengal       Cyclone              12
# 38        Bihar       Unknown              23
# 39  West Bengal       Drought              22
# 40       Kerala       Cyclone              17
# 41           UP         Flood              17
# 42           UP    Earthquake              21
# 43        Assam         Flood              17
# 44       Odisha     Landslide              17
# 45       Kerala     Landslide              13
# 46        Bihar     Landslide              20
# 47   Tamil Nadu       Cyclone              28

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\kavya\appdata\local\programs\python\python311\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kavya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kavya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kavya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kavya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\kavya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\kavya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\kavya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\kavya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kavya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kavya\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\kavya\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.bar(top_regions['region'], top_regions['total_affected'])

plt.title("Top 5 Regions by Total Affected Population")
plt.xlabel("Region")
plt.ylabel("Total Affected People")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
plt.figure()

plt.bar(severity_dist['disaster_type'], severity_dist['disaster_count'])

plt.title("Disaster Distribution by Type")
plt.xlabel("Disaster Type")
plt.ylabel("Number of Events")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
plt.figure()

plt.plot(monthly_trend['date'], monthly_trend['disaster_count'])

plt.title("Monthly Disaster Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Number of Disasters")

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
monthly_trend['date'] = pd.to_datetime(
    monthly_trend['year'].astype(str) + '-' +
    monthly_trend['month'].astype(str) + '-01'
)

monthly_trend = monthly_trend.sort_values('date')

# %%
plt.figure()

plt.scatter(
    scatter_data['affected_people'],
    scatter_data['economic_loss_musd']
)

plt.title("Economic Loss vs Affected Population")
plt.xlabel("Affected People")
plt.ylabel("Economic Loss (Million USD)")

plt.tight_layout()
plt.show()

# %%
pivot = heatmap_data.pivot(
    index='region',
    columns='disaster_type',
    values='disaster_count'
)

pivot = pivot.fillna(0)

# %%
plt.figure()

plt.imshow(pivot)
plt.colorbar()

plt.xticks(range(len(pivot.columns)), pivot.columns, rotation=45)
plt.yticks(range(len(pivot.index)), pivot.index)

plt.title("Region-wise Disaster Frequency Heatmap")

plt.tight_layout()
plt.show()
